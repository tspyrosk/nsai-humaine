# %% [markdown]
# # LTN Training Notebook
#
# This notebook follows the exact logic of `train_ltn.py`. Modify any part of the training pipeline as needed.
#
# **Instructions:**
# 1. Run cells sequentially
# 2. Modify hyperparameters, model architecture, or training logic as desired
# 3. The trained model will be saved to `/app/output/ltn_notebook.h5`
# 4. Return to Streamlit Explain tab to use the trained model

# %% [markdown]
# ## Imports and Setup

# %%
import sys
import os

# Add app directory to path for imports
if '/app' not in sys.path:
    sys.path.insert(0, '/app')

import ltn
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report, balanced_accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import random
import time
import json
import warnings
warnings.filterwarnings("ignore")

# Import utility functions (same as train_ltn.py)
from utils import normalize_value, random_oversample
from paths import OUTPUT_DIR, LTN_RULES_PATH

# Paths
TRAIN_DIR = os.path.join(OUTPUT_DIR, "train")
TEST_DIR = os.path.join(OUTPUT_DIR, "test")

print("Imports loaded")
# Out:
# 2026-03-08 18:05:09.352132: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-08 18:05:09.370918: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-08 18:05:09.376794: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-08 18:05:09.390474: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Configuration

# %%
# Hyperparameters - modify these as needed (same defaults as train_ltn.py)
BATCH_SIZE = 32
EPOCHS = 1000
LEARNING_RATE = 0.001
RANDOM_SEED = 99  # Default seed from train_ltn.py

# Set random seeds (same as train_ltn.py lines 41-44)
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.keras.utils.set_random_seed(RANDOM_SEED)
tf.config.experimental.enable_op_determinism()

print(f"Configuration set: {EPOCHS} epochs, batch size {BATCH_SIZE}, LR {LEARNING_RATE}, seed {RANDOM_SEED}")
# Out:
# Configuration set: 1000 epochs, batch size 32, LR 0.001, seed 99

# %% [markdown]
# ## Load Data

# %%
# Load training and test data (same as train_ltn.py lines 59-62)
X_train = np.load(f'{TRAIN_DIR}/X_{RANDOM_SEED}.npy')
y_train = np.load(f'{TRAIN_DIR}/y_{RANDOM_SEED}.npy')
X_test = np.load(f'{TEST_DIR}/X_{RANDOM_SEED}.npy')
y_test = np.load(f'{TEST_DIR}/y_{RANDOM_SEED}.npy')

print(f"Data loaded for seed {RANDOM_SEED}")
print(f"Train: {X_train.shape}, Test: {X_test.shape}")
print(f"Train labels: {np.sum(y_train)} positive, {len(y_train) - np.sum(y_train)} negative")
# Out:
# Data loaded for seed 99
# Train: (559, 9), Test: (140, 9)
# Train labels: 191 positive, 368 negative

# %% [markdown]
# ## LTN Operators

# %%
# Define LTN operators
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2), semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2), semantics="exists")

formula_aggregator = ltn.Wrapper_Formula_Aggregator(ltn.fuzzy_ops.Aggreg_pMeanError(p=2))

print("LTN operators defined")
# Out:
# LTN operators defined

# %% [markdown]
# ## Load Predicates

# %%
# Load predicates from saved file (generated from Streamlit)
# This matches the exact approach in train_ltn.py lines 84-86
with open(f"{OUTPUT_DIR}/predicates.txt", 'r') as file:
    preds_code = file.read()

# Execute predicates code to define them in this namespace
# Note: This requires X_train, normalize_value, ltn, tf, Not to be available
exec(preds_code, globals())

print("Predicates loaded from predicates.txt")
print("Available predicates:")
print(preds_code[:500] + "..." if len(preds_code) > 500 else preds_code)
# Out:
# Predicates loaded from predicates.txt
# Available predicates:
# import tensorflow as tf
# import ltn
#
# normalized_clump_thickness_high = normalize_value(X_train, 0, 5.0)
# normalized_mitoses_low = normalize_value(X_train, 8, 5.0)
#
# clump_thickness_high = ltn.Predicate(lambda x: tf.math.greater(x[:, 0], normalized_clump_thickness_high))
# mitoses_low = ltn.Predicate(lambda x: tf.math.less(x[:, 8], normalized_mitoses_low))
#
# global malignant
# global no_malignant
# global target
# global no_target
#
# malignant = lambda x, y: f(x)
# no_malignant = lambda x, y: Not(f(x))
# target = ...

# %% [markdown]
# ## Define Model

# %%
# Define the main predicate model (same as train_ltn.py line 88-90)
global f

f = ltn.Predicate.MLP(
    [(X_train.shape[1],)],
    hidden_layer_sizes=(8, 8)
)

print(f"Model defined with input size {X_train.shape[1]}")
# Out:
# Model defined with input size 9

# %% [markdown]
# ## Load Rules and Define Axioms

# %%
# Load rules and define axioms (same as train_ltn.py lines 92-108)
USE_RULES = True  # Set to False to train without rules (MLP only)
rules_file_path = LTN_RULES_PATH  # Uses path from paths.py

def get_axioms(X_train, y_train, use_rules):
    """Get axioms for training - matches train_ltn.py exactly."""
    x = ltn.Variable("x", X_train)
    y = ltn.Variable("y", y_train)
    x_A = ltn.Variable("x_A", tf.boolean_mask(X_train, y_train))
    x_not_A = ltn.Variable("x_not_A", tf.boolean_mask(X_train, tf.logical_not(tf.cast(y_train, tf.bool))))
    
    base_axioms = [
        Forall(x_A, target(x_A, f(x_A))),
        Forall(x_not_A, no_target(x_not_A, f(x_not_A)))
    ]

    axioms = base_axioms
    if use_rules:
        with open(rules_file_path, 'r') as file:
            rules_from_file = file.read()
        exec(rules_from_file, globals())
        axioms = base_axioms + parsed_rules(x, y)
    return axioms

# Test axiom generation
test_axioms = get_axioms(X_train[:10], y_train[:10], USE_RULES)
print(f"USE_RULES: {USE_RULES}")
print(f"Rules file: {rules_file_path}")
print(f"Total axioms: {len(test_axioms)}")
# Out:
# USE_RULES: True
# Rules file: /app/output/ltn_rules.txt
# Total axioms: 3

# %% [markdown]
# ## Training Function

# %%
# Training function (matches train_ltn.py lines 111-188)
# Note: Model saved as 'ltn_notebook.h5' instead of 'ltn.h5' to avoid overwriting CLI-trained models

def train(X_train_full, y_train_full, epochs, use_rules, log=False):
    """Train the LTN model - matches train_ltn.py train() function."""
    
    # Split into train/val (80/20) - same as train_ltn.py line 132
    indices = np.arange(len(X_train_full))
    train_idx, val_idx = train_test_split(indices, test_size=0.2, random_state=RANDOM_SEED)

    X_train, y_train = X_train_full[train_idx], y_train_full[train_idx]
    X_train, y_train = random_oversample(X_train, y_train, random_state=RANDOM_SEED)

    X_val, y_val = X_train_full[val_idx], y_train_full[val_idx]

    print(f"Training on {len(X_train)} samples, validating on {len(X_val)} samples")

    # Optimizer - same as train_ltn.py line 142
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

    losses = []
    val_losses = []
    val_loss_min = 1e6
    last_saved_epoch = 0

    start_time = time.time()
    
    for epoch in range(epochs):
        # Training step - same as train_ltn.py lines 151-157
        with tf.GradientTape() as tape:
            axioms = get_axioms(X_train, y_train, use_rules)
            sat_level = formula_aggregator(axioms).tensor
            loss = 1. - sat_level
        gradients = tape.gradient(loss, f.trainable_variables)
        optimizer.apply_gradients(zip(gradients, f.trainable_variables))
        losses.append(loss.numpy())

        # Validation step - same as train_ltn.py lines 159-162
        val_axioms = get_axioms(X_val, y_val, use_rules)
        val_sat = formula_aggregator(val_axioms).tensor
        val_loss = 1. - val_sat
        val_losses.append(val_loss.numpy())

        # Save best model - same as train_ltn.py lines 164-169
        if val_loss < val_loss_min:
            if log:
                print(f'Epoch: {epoch}: Val loss reduced to {val_loss}. Saving model.')
            f.model.save(f'{OUTPUT_DIR}/ltn_notebook.h5')
            val_loss_min = val_loss
            last_saved_epoch = epoch

        # Progress logging - same as train_ltn.py lines 171-179
        if epoch % 100 == 0:
            print(f'Epoch: {epoch}')
            print(f'Train Sat: {sat_level.numpy():.4f}')
            print(f'Val Sat: {val_sat.numpy():.4f}')
            print(f'Last Saved Epoch: {last_saved_epoch}')

    end_time = time.time()
    total_time = end_time - start_time

    print(f"\nTraining complete in {total_time:.1f}s ({total_time/epochs:.3f}s per epoch)")
    print(f"Best model saved at epoch {last_saved_epoch}")

    return losses, val_losses, last_saved_epoch

print("Training function defined")
# Out:
# Training function defined

# %% [markdown]
# ## Run Training

# %%
# Train the model (same as train_ltn.py line 190)
print("Starting training...")
print("=" * 60)

losses, val_losses, best_epoch = train(
    X_train,
    y_train,
    epochs=EPOCHS,
    use_rules=USE_RULES
)

print("=" * 60)
print("Training finished!")
# Out:
# Starting training...
# ...
# Training on 582 samples, validating on 112 samples
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch: 0
# Train Sat: 0.7032
# Val Sat: 0.6957
# Last Saved Epoch: 0
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %% [markdown]
# ## Evaluation

# %%
# Load best model and evaluate on test set (same as train_ltn.py lines 193-216)
saved_model = tf.keras.models.load_model(f'{OUTPUT_DIR}/ltn_notebook.h5')

y_pred = saved_model(X_test).numpy()
preds = (y_pred > 0.5).astype(int).flatten()

# Calculate metrics (same as train_ltn.py lines 198-202)
report = classification_report(y_test, preds)
bal_acc = balanced_accuracy_score(y_test, preds)
precision = precision_score(y_test, preds)
recall = recall_score(y_test, preds)
f1 = f1_score(y_test, preds)

# Validation failures (same as train_ltn.py line 204)
val_failures = np.where(preds != y_test)[0]

print("=" * 60)
print("EVALUATION RESULTS")
print("=" * 60)
print(report)
print(f"\nBalanced Accuracy: {bal_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"\nValidation failures: {len(val_failures)} samples")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ...
# EVALUATION RESULTS
# ...
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95        90
#            1       0.87      0.96      0.91        50
#
#     accuracy                           0.94       140
#    macro avg       0.92      0.94      0.93       140
# weighted avg       0.94      0.94      0.94       140
#
#
# Balanced Accuracy: 0.9411
# Precision: 0.8727
# Recall: 0.9600
# F1 Score: 0.9143
#
# Validation failures: 9 samples

# %% [markdown]
# ## Save Metadata

# %%
# Save model metadata (similar to train_ltn.py METADATA structure)
metadata = {
    "Model Type": "LTN",
    "Model Version": "v0.1",
    "Knowledge Representation": "LTN",
    "Hyperparameters": {
        "learning_rate": LEARNING_RATE,
        "batch_size": BATCH_SIZE,
        "epochs": EPOCHS
    },
    "Optimizer": {
        "type": "Adam",
        "config": {"lr": LEARNING_RATE},
        "loss_metric": "sat"
    },
    "Loss Metric": "sat",
    "Rules File": rules_file_path if USE_RULES else None,
    "Post-training Evaluation Metrics": {
        "balanced accuracy": float(bal_acc),
        "precision": float(precision),
        "recall": float(recall),
        "f1_score": float(f1)
    },
    "Validation Failure Cases": val_failures.tolist(),
    "seed": RANDOM_SEED,
    "n_features": X_train.shape[1],
    "n_train_samples": X_train.shape[0],
    "use_rules": USE_RULES,
    "best_epoch": best_epoch,
    "trained_at": time.strftime("%Y-%m-%d %H:%M:%S")
}

metadata_path = os.path.join(OUTPUT_DIR, "ltn_notebook_metadata.json")
with open(metadata_path, 'w') as file:
    json.dump(metadata, file, indent=2)

print(f"Metadata saved to {metadata_path}")
print("\nYou can now use this model in the Streamlit Explain tab!")
# Out:
# Metadata saved to /app/output/ltn_notebook_metadata.json
#
# You can now use this model in the Streamlit Explain tab!

# %% [markdown]
# ## Training History Visualization

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Loss plot
ax1.plot(losses, label='Train Loss', alpha=0.7)
ax1.plot(val_losses, label='Val Loss', alpha=0.7)
ax1.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch})')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Progress')
ax1.legend()
ax1.grid(alpha=0.3)

# Satisfiability plot (1 - loss)
train_sat = [1 - l for l in losses]
val_sat = [1 - l for l in val_losses]
ax2.plot(train_sat, label='Train Sat', alpha=0.7)
ax2.plot(val_sat, label='Val Sat', alpha=0.7)
ax2.axvline(x=best_epoch, color='r', linestyle='--', label=f'Best Epoch ({best_epoch})')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Satisfiability')
ax2.set_title('Satisfiability Level')
ax2.legend()
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()
